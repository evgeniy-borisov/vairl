# %% [markdown]
# <a href="https://colab.research.google.com/github/evgeniy-borisov/vairl/blob/main/notebooks/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Пример ноутбука VAIRL
#
# Шаблон для публикации примеров кода в Google Colab.

# %%
print("Hello from VAIRL Colab example")
